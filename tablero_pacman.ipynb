# %% [markdown]
# # Tabla del JUEGO

# %%
"""
Tablero del Juego Gato y Ratón
Representación visual de un laberinto grande con posiciones iniciales y objetivos
"""

print('------------------------------------------')

# Definimos Variables 
raton = "🐭"
R = raton

gato = "🐱"
G = gato

queso = "🧀"
Q = queso

meta = "M"
M = meta

pared = "#"
P = pared

vacio = '.'
V = vacio

d = ""

print('-------------------------------------------')

tablero = [
    [P,G,P,P,P,P,P,P,P], 
    [M,V,P,Q,V,V,V,V,P], 
    [P,V,P,V,V,P,P,V,P], 
    [P,V,P,V,V,P,P,V,P], 
    [P,V,P,V,V,P,P,V,P], 
    [P,V,P,V,V,V,V,V,P], 
    [P,V,P,V,V,P,P,V,P], 
    [P,V,P,P,V,P,P,V,P], 
    [P,V,V,V,V,V,V,V,P], 
    [P,P,P,P,P,P,P,R,P]
]

# %% [markdown]
# # JUEGO

# %%
#importamos la libreria "time" para poder hacer la cuenta regresiva.
import time

# Wins
def excelente():
    print("⭐⭐⭐")
    print(f'Felicidades haz ganado, tienes 3/3 estrellas.')

def bien():
    print("⭐⭐")
    print(f'Bien hecho, tienes 2/3 estrellas.')

def meh():
    print("⭐")
    print(f'haz obtenido 1/3 estrellas.')

# Defeat
def gameover():
    print(f'GAME OVER, Obtienes 0/3 estrellas, mala suerte... ')

# Definimos Variables 
raton = "🐭"
R = raton

gato = "🐱"
G = gato

queso = "🧀"
Q = queso

meta = "M"
M = meta

pared = "#"
P = pared

vacio = '.'
V = vacio

# Definimos una tabla (mejor distribuida visualmente)
tablero = [
    [P,P,P,P,P,P,P,P,P],
    [P,G,V,V,P,V,Q,V,P],
    [P,V,P,V,P,V,P,V,P],
    [P,V,P,V,V,V,P,V,P],
    [P,V,P,P,P,V,P,V,P],
    [P,V,V,V,P,V,V,V,P],
    [P,P,P,V,P,P,P,V,P],
    [P,V,V,V,V,V,P,V,P],
    [P,M,P,P,P,V,V,V,P],
    [P,P,P,P,P,P,P,R,P]
]

def distancia_manhattan(f1, c1, f2, c2):
    return abs(f1 - f2) + abs(c1 - c2)

#funcion que hace una cuenta atras.
def cuenta_atras():
    duracion = 300
    tiempo_restante = int(duracion - (tiempo_actual - tiempo_inicio))
    if tiempo_restante < 0:
        tiempo_restante = 0
    minutos = tiempo_restante // 60
    segundos = tiempo_restante % 60
    print(f"╔══════════════════════╗")
    print(f"║{minutos:02}:{segundos:02}║")
    print(f"╚══════════════════════╝")

#funcion que imprime el tablero.
def mostrar_tablero():
    print(f"\nTurno de: {turno_actual}")
    for fila in tablero:
        print(" ".join(fila))

#Establecemos el tiempo de inicio.
tiempo_inicio = time.time()

movimientos_gato = [
    (-1, 0),
    (1, 0),
    (0, -1),
    (0, 1)
]

def minimax(tablero, fila_gato, col_gato, fila_raton, col_raton, profundidad, es_turno_gato):

    if fila_gato == fila_raton and col_gato == col_raton:
        return 1000

    if profundidad == 0:
        distancia = distancia_manhattan(fila_gato, col_gato, fila_raton, col_raton)
        return -distancia

    if es_turno_gato:
        mejor_valor = -99999

        for mov in movimientos_gato:
            nueva_fila = fila_gato + mov[0]
            nueva_col = col_gato + mov[1]

            if (0 <= nueva_fila < len(tablero)) and \
               (0 <= nueva_col < len(tablero[0])) and \
               tablero[nueva_fila][nueva_col] != P:

                valor = minimax(
                    tablero,
                    nueva_fila,
                    nueva_col,
                    fila_raton,
                    col_raton,
                    profundidad - 1,
                    False
                )

                mejor_valor = max(mejor_valor, valor)

        return mejor_valor

    else:
        peor_valor = 99999
        movimientos_raton = [(-1,0),(1,0),(0,-1),(0,1)]

        for mov in movimientos_raton:
            nueva_fila = fila_raton + mov[0]
            nueva_col = col_raton + mov[1]

            if (0 <= nueva_fila < len(tablero)) and \
               (0 <= nueva_col < len(tablero[0])) and \
               tablero[nueva_fila][nueva_col] != P:

                valor = minimax(
                    tablero,
                    fila_gato,
                    col_gato,
                    nueva_fila,
                    nueva_col,
                    profundidad - 1,
                    True
                )

                peor_valor = min(peor_valor, valor)

        return peor_valor

def mejor_movimiento_gato():
    global fila_gato, columna_gato
    mejor_valor = -99999
    mejor_mov = None

    for mov in movimientos_gato:
        nueva_fila = fila_gato + mov[0]
        nueva_col = columna_gato + mov[1]

        if (0 <= nueva_fila < len(tablero)) and \
           (0 <= nueva_col < len(tablero[0])) and \
           tablero[nueva_fila][nueva_col] != P:

            valor = minimax(
                tablero,
                nueva_fila,
                nueva_col,
                fila_raton,
                columna_raton,
                3,
                False
            )

            if valor > mejor_valor:
                mejor_valor = valor
                mejor_mov = (nueva_fila, nueva_col)

    return mejor_mov

#funcion que actualiza el tablero.
def actualizar_tablero():
    print("\n----------------------------------")
    cuenta_atras()
    print("\n----------------------------------")
    mostrar_tablero()

# Posiciones iniciales
fila_raton = 9
columna_raton = 7

fila_gato = 1
columna_gato = 1

# Estados
tiene_queso = False
turno_raton_extra = 2
turno_actual = "RATON"
tiempo_queso = None

# Mostrar tablero inicial.
mostrar_tablero()

# Bucle del juego
while True:
    tiempo_actual = time.time()

    if turno_actual == "RATON":
        movimiento = input("Mueva con W/A/S/D, X para salir: ")

        if movimiento.upper() == "X":
            break

        movido = False

        if movimiento.upper() == "W":
            nueva_fila = fila_raton - 1
            nueva_columna = columna_raton

        elif movimiento.upper() == "A":
            nueva_fila = fila_raton
            nueva_columna = columna_raton - 1

        elif movimiento.upper() == "S":
            nueva_fila = fila_raton + 1
            nueva_columna = columna_raton

        elif movimiento.upper() == "D":
            nueva_fila = fila_raton
            nueva_columna = columna_raton + 1
        else:
            print("Movimiento inválido.")
            actualizar_tablero()
            continue

        if not ((0 <= nueva_fila < len(tablero)) and (0 <= nueva_columna < len(tablero[0]))):
            print("Movimiento inválido: fuera del tablero.")
            actualizar_tablero()
            continue

        if tablero[nueva_fila][nueva_columna] == P:
            print("Movimiento inválido: pared.")
            actualizar_tablero()
            continue

        destino = tablero[nueva_fila][nueva_columna]

        if destino == Q:
            tiene_queso = True
            turno_raton_extra = 3
            tiempo_queso = int(tiempo_actual - tiempo_inicio)
            print("🧀 ¡Queso obtenido! Ahora tienes 3 turnos seguidos.")

        if destino == M:
            tiempo_final = int(tiempo_actual - tiempo_inicio)
            print(f"⏱️ Tiempo total: {tiempo_final} segundos")

            if tiene_queso and tiempo_final <= 60:
                excelente()
            elif tiene_queso:
                bien()
            else:
                meh()
            break

        tablero[fila_raton][columna_raton] = V
        tablero[nueva_fila][nueva_columna] = R
        fila_raton = nueva_fila
        columna_raton = nueva_columna

        turno_raton_extra -= 1

        if turno_raton_extra > 0:
            turno_actual = "RATON"
        else:
            turno_actual = "GATO"
            turno_raton_extra = 2 if not tiene_queso else 3

    else:
        mov_gato = mejor_movimiento_gato()

        if mov_gato is not None:
            tablero[fila_gato][columna_gato] = V
            fila_gato, columna_gato = mov_gato
            tablero[fila_gato][columna_gato] = G

        if fila_gato == fila_raton and columna_gato == columna_raton:
            gameover()
            break

        turno_actual = "RATON"

    actualizar_tablero()
# Out:
# Turno de: RATON
# # # # # # # # # #
# # 🐱 . . # . 🧀 . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # 🐭 #
# ----------------------------------
# ╔══════════════════════╗
# ║04:59║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # 🐱 . . # . 🧀 . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . 🐭 #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║04:42║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # 🐱 . . # . 🧀 . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # 🐭 #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║04:34║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . 🧀 . #
# # 🐱 # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # 🐭 #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║04:34║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . 🧀 . #
# # 🐱 # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # 🐭 #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║04:06║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # . . . # . 🧀 . #
# # 🐱 # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . 🐭 #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║04:04║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . 🧀 . #
# # . # . # . # . #
# # 🐱 # . . . # . #
# # . # # # . # . #
# # . . . # . . 🐭 #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║04:04║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . 🧀 . #
# # . # . # . # . #
# # 🐱 # . . . # . #
# # . # # # . # 🐭 #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:57║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # . . . # . 🧀 . #
# # . # . # . # . #
# # 🐱 # . . . # 🐭 #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:56║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . 🧀 . #
# # 🐱 # . # . # . #
# # . # . . . # 🐭 #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:56║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . 🧀 . #
# # 🐱 # . # . # 🐭 #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:55║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # . . . # . 🧀 🐭 #
# # 🐱 # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:54║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # 🐱 . . # . 🧀 🐭 #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
# 🧀 ¡Queso obtenido! Ahora tienes 3 turnos seguidos.
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:54║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # 🐱 . . # . 🐭 . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:53║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # 🐱 . . # 🐭 . . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
# Movimiento inválido.
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:50║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # 🐱 . . # 🐭 . . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:48║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # 🐱 . . # . 🐭 . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:45║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . 🐱 . # . 🐭 . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
# Movimiento inválido: pared.
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:45║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . 🐱 . # . 🐭 . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
# Movimiento inválido: pared.
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:44║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . 🐱 . # . 🐭 . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:39║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . 🐱 . # . . 🐭 #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:37║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . 🐱 . # . . . #
# # . # . # . # 🐭 #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:36║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # . 🐱 . # . . . #
# # . # . # . # . #
# # . # . . . # 🐭 #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:34║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . 🐱 # . . . #
# # . # . # . # . #
# # . # . . . # 🐭 #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:34║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . 🐱 # . . . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # 🐭 #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:34║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . 🐱 # . . . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . 🐭 #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:33║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # . . 🐱 # . . . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # 🐭 #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:32║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # 🐱 # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # 🐭 #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:32║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # 🐱 # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # 🐭 #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:32║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # 🐱 # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . 🐭 #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:31║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # . . . # . . . #
# # . # 🐱 # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . 🐭 . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:30║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # 🐱 . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . 🐭 . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:30║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # 🐱 . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # 🐭 . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:29║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # 🐱 . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . 🐭 # . #
# # M # # # . . . #
# # # # # # # # . #
# Movimiento inválido.
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:28║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # 🐱 . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . . 🐭 # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:28║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # 🐱 . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . 🐭 . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:27║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # . 🐱 . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . . 🐭 . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:27║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # . 🐱 . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . 🐭 . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:26║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # . 🐱 . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . 🐭 . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:26║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # . 🐱 . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . 🐭 . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:25║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # 🐱 . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . 🐭 . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:25║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # 🐱 . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # 🐭 # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:25║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # 🐱 . . # . #
# # . # # # . # . #
# # . . 🐭 # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
# Movimiento inválido.
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:24║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # 🐱 . . # . #
# # . # # # . # . #
# # . . 🐭 # . . . #
# # # # . # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:22║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # . . . # . . . #
# # . # . # . # . #
# # . # 🐱 . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # 🐭 # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:21║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # 🐱 # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # 🐭 # # # . #
# # . . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:21║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # 🐱 # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . . 🐭 . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:20║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . . # . . . #
# # . # 🐱 # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # . 🐭 . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:20║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: GATO
# # # # # # # # # #
# # . . . # . . . #
# # . # 🐱 # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # 🐭 . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:19║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . 🐱 # . . . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # 🐭 . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
# Movimiento inválido.
#
# ----------------------------------
# ╔══════════════════════╗
# ║03:19║
# ╚══════════════════════╝
#
# ----------------------------------
#
# Turno de: RATON
# # # # # # # # # #
# # . . 🐱 # . . . #
# # . # . # . # . #
# # . # . . . # . #
# # . # # # . # . #
# # . . . # . . . #
# # # # . # # # . #
# # 🐭 . . . . # . #
# # M # # # . . . #
# # # # # # # # . #
# ⏱️ Tiempo total: 101 segundos
# ⭐⭐
# Bien hecho, tienes 2/3 estrellas.

# %% [markdown]
# # Mensajes del juego

# %%
# Wins
def excelente():
    print (f'Felicidades haz ganado, tienes 3/3 estrellas.')

def bien():
    print (f'Bien hecho, tienes 2/3 estrellas.')

def meh():
    print (f'haz obtenido 1/3 estrellas.')


# Defeat

def gameover():
    print (f'GAME OVER, Obtienes 0/3 estrellas, mala suerte... ')

excelente()
bien()
meh()

gameover()
